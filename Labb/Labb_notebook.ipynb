# %%
import numpy as np
from scipy import stats
from LinearRegression import LinearRegression

data = np.genfromtxt(
    "../Data/housing.csv",
    delimiter=",",
    names=True,
    dtype=None,
    encoding="utf-8")


data.shape, data.dtype.fields
# Out:
# ((20640,),
#  mappingproxy({'longitude': (dtype('float64'), 0),
#                'latitude': (dtype('float64'), 8),
#                'housing_median_age': (dtype('float64'), 16),
#                'total_rooms': (dtype('float64'), 24),
#                'total_bedrooms': (dtype('float64'), 32),
#                'population': (dtype('float64'), 40),
#                'households': (dtype('float64'), 48),
#                'median_income': (dtype('float64'), 56),
#                'median_house_value': (dtype('float64'), 64),
#                'ocean_proximity': (dtype('<U10'), 72)}))

# %% [markdown]
# Vi har n = 20640 observationer. 10 stycken kolonner.
# ### 8 numeriska X:longitude,latitude,housing_median_age,total_rooms,total_bedrooms,population,households,median_income,median_house_value
# ### 1 kategoriskt X: ocean_proximity
# ### 1 Y: median_house_value

# %% [markdown]
# #### Ocean har 5 olika kategorier:
# <1H OCEAN - 9136
# INLAND - 6551
# ISLAND - 5
# NEAR BAY - 2290
# NEAR OCEAN - 2658
#
# Värt att notera att "ISLAND" är endast 5.

# %%
X = np.column_stack([
    np.ones(len(median_income)),  # intercept
    housing_median_age,
    total_rooms,
    total_bedrooms,
    population,
    households,
    median_income
])

model = LinearRegression()
model.fit(X,y)

corr = model.pearson()
print(corr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 X = np.column_stack([
# ----> 2     np.ones(n),
#       3     housing_median_age,
#       4     total_rooms,
#       5     total_bedrooms,
#       6     population,
#       7     households,
#       8     median_income
#       9 ])
#      11 model = LinearRegression()
#      12 model.fit(X,y)
#
# NameError: name 'n' is not defined
